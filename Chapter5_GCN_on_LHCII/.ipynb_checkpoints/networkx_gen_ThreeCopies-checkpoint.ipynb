# %%
#This script is to generate network x object directly from xyz + tresp.
import re
from itertools import combinations
from math import sqrt
import math
import pandas as pd
import networkx as nx
import numpy as np
import torch
from torch_geometric.data import DataLoader
from torch.autograd import Variable
from torch.utils.data.sampler import SubsetRandomSampler
from my_dataset_4cluster_2 import *
from torch_geometric import utils
from torch_geometric.data import Data

# %%
My_dataset()[0]
# Out:
# Data(X=[508, 6], edge_attr=[43928], edge_index=[2, 43928], y=470.0)

# %%
def split_structure_connect(panda_df):
    """
    Given a pandas dataframe, spit out the data part and CONNECT part as two panda frames
    """
    CONNECT_START, CONNECT_END = 0,0
    for idx, row in panda_df.iterrows():
        if row[0] == "TER":
            CONNECT_START = idx
        if row[0] == "END":
            CONNECT_END = idx
    #print(CONNECT_START, CONNECT_END)    
    return (panda_df.iloc[0:CONNECT_START], panda_df.iloc[CONNECT_START+1:CONNECT_END])

def read_file(file_path):
    #read the file at file_path and return its structure and connect info.
    print('reading data from path:')
    print(str(file_path))
    data = pd.read_csv(file_path, 
                         header=None, 
                         delim_whitespace=True, 
                         keep_default_na=False, 
                         na_values=[''], 
                         names = ['a', 'b', 'c', 'd', 'e', "f"], engine='python')
    data_structure, data_CONNECT = split_structure_connect(data)
    data_structure = data_structure.drop(labels='f', axis=1)
    
    return (data_structure, data_CONNECT)    

def node_gen(file_path):
    #given the structure infomation, initialize the graph and generate only nodes.
    G = nx.Graph()
    for i, (element, x, y, z, tresp) in enumerate(read_file(file_path)[0].values):
        element = element[0]
        if element == 'M':
            element = 'Mg'
        G.add_nodes_from([i+1], 
                         atom_x = x, 
                         atom_y = float(y), 
                         atom_z = z, 
                         atom_tresp = tresp, 
                         atom_type = element, 
                        )
    return G

def list_bond_gen(file_path):
    #add the covalent bond to the edge index from the info provided by connect data.
    list_bond = [] #a list that record the [starting atom, end atom]
    #print('processing mol:')
    #print(file_path[0][7:13])
    for line in read_file(file_path)[1].iterrows():
        i = 0
        for element in line[1][1:]: # skip the CONNECT element, the rest element in this for loop are need to be connected.
            if str(element) != "nan": # skip the nan elements.
                if i == 0: #i.e. the start of the for loop. the first element.
                    atom_start = int(element)
                    #print("the starting atom is:")
                    #print(atom_start)
                    i+=1
                else: #the second, third... fourth of the element.
                    atom_connect = int(element)
                    #print("the connecting atom is:")
                    #print(atom_connect)
                    
                    list_bond.append([atom_start, atom_connect])
                    i+=1
    return (list_bond)

def covalent_bond_gen(G, list_bond):
    #takes in the graph(with only nodes now), 
    #and the list of bond (generated from connect info)
    #and spit out the covalent bonded graph.
    G.add_edges_from(list_bond)
    return G
    

def covalent_graph_gen(file_path):
    #generate a graph with the covalent bond.
    G = node_gen(file_path)
    covalent_bond_gen(G, list_bond_gen(file_path))
    return G

def combine_graph(G_local, H_local):
    #takes in two graph G and H; combine it.
    H_new = nx.Graph() #initialize the new graph
    for i in range(len(H_local.nodes)):
        #adding the nodes from H, preserving its attr
        H_new.add_nodes_from(
        [
        ((i+len(G_local.nodes)+1),
        H_local.nodes[i+1])
        ]
    )
        #adding the edges from H, preserving its attr
        H_new.add_edges_from(
        
            new_edges(H_local.edges, len(G_local.nodes))
        
    )
    #print(H_new.nodes)
    #print(G.nodes)
    U = nx.compose(G_local, H_new)
    return U

def generate_4_cluster_graph(list_file_path):
    #fist we generate the 4 seperate graphs.
    G1 = covalent_graph_gen(list_file_path[0])
    G2 = covalent_graph_gen(list_file_path[1])
    G3 = covalent_graph_gen(list_file_path[2])
    G4 = covalent_graph_gen(list_file_path[3])
    
    #here we set up the node molname attribute:
    G1.add_nodes_from((G1.nodes), molname = 1)
    G2.add_nodes_from((G2.nodes), molname = 1)
    G3.add_nodes_from((G3.nodes), molname = 1)
    G4.add_nodes_from((G4.nodes), molname = 2)
    
    print("The node number for each graph are:")
    print(len(G1.nodes), len(G2.nodes), len(G3.nodes), len(G4.nodes))
    
    #here we combine the graphs into a giant graph.(no inter-mol connected yet)
    U = combine_graph(G1,G2)
    U = combine_graph(U, G3)
    U = combine_graph(U, G4)
    
    print('The combined graph node number is: %d' %(len(U.nodes)))
    
    #here we set up the edge covalent_bond_weight attribute
    U.add_edges_from((U.edges), bond_weight = 1)
    
    return U

# %%
#file_path = ['./data/CLA610/frame0.csv']
#file_path_2 = ['./data/LUT620/frame1.csv']
#G = covalent_graph_gen(file_path)
#H = covalent_graph_gen(file_path_2)

# %%
#U = combine_graph(G,H)

# %%
def new_edges(list_edges, len_other_graph):
    new_list_edges = []
    for element in list_edges:
        new_start = element[0] + len_other_graph
        new_end = element[1] + len_other_graph
        new_list_edges.append((new_start, new_end))
    #print(new_list_edges)
    return new_list_edges

# %%
list_file_path = ['./data/CLA610/frame0.csv',
                  './data/CLA611/frame0.csv',
                  './data/CLA612/frame0.csv',
                  './data/LUT620/frame0.csv']

list_file_path = ['./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame1.csv',
                  './data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame1.csv',
                  './data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame1.csv',
                  './data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame1.csv']   #data\ThreeCopies\7_1_1_conect_lifetimes\CLA610
covalent_bond_weight = 1

# %%
U_test = generate_4_cluster_graph(list_file_path)
# Out:
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame1.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508

# %%
for node in U_test.nodes.items():
    print(node)
    print(node[1]['atom_y'])
    break
# Out:
# (1, {'atom_x': 83.213, 'atom_y': 65.916, 'atom_z': 29.292, 'atom_tresp': -0.000723, 'atom_type': 'C', 'molname': 1})
# 65.916

# %%
import math
def adding_intermol_edge(Graph, distance_cutoff, inter_mol_K):
    #iterating the nodes in the graph, using node attrbute xyz to calculate the distance
    #if distance smaller than cutoff, define a edge between this 2 nodes
    #this also add bond_weight as parameter
    
    inter_mol_edge_list = []
    
    for node_1 in Graph.nodes.items():
        node_1_num = node_1[0]
        node_1_att = node_1[1]
        for node_2 in Graph.nodes.items():
            node_2_num = node_2[0]
            node_2_att = node_2[1]
            if node_1_num >= node_2_num:
                continue
            else:
                x1, y1, z1 = float(node_1_att['atom_x']), float(node_1_att['atom_y']), float(node_1_att['atom_z'])
                x2, y2, z2 = float(node_2_att['atom_x']), float(node_2_att['atom_y']), float(node_2_att['atom_z'])
                distance = sqrt((x1-x2)**2 + (y1-y2)**2 + (z1-z2)**2)
                if distance < distance_cutoff:
                    inter_mol_edge_list.append([node_1_num, node_2_num])
    print('within the cutoff, the inter mol are:')
    print(len(inter_mol_edge_list))
    #print(inter_mol_edge_list)
    
    #now that we find out all the pair-wise inter-mol interactions
    #time to give them edge and bond_weight
    
    Graph_new = Graph.copy()
    
    Graph_new.add_edges_from(inter_mol_edge_list, bond_weight = inter_mol_K)
    Graph_new.add_edges_from((Graph.edges), bond_weight = 1) #make the original covalent bond to 1.
    
    return Graph_new

# %%
U_test2 = adding_intermol_edge(U_test, 7.5, 0.2)
# Out:
# within the cutoff, the inter mol are:
# 21303

# %%
print(len(U_test2.nodes), len(U_test2.edges))
# Out:
# 508 21303

# %%
list(U_test2.edges(data= True))
# Out:
# [(1, 4, {'bond_weight': 0.2}),
#  (1, 5, {'bond_weight': 0.2}),
#  (1, 6, {'bond_weight': 0.2}),
#  (1, 9, {'bond_weight': 0.2}),
#  (1, 10, {'bond_weight': 0.2}),
#  (1, 11, {'bond_weight': 0.2}),
#  (1, 12, {'bond_weight': 0.2}),
#  (1, 13, {'bond_weight': 0.2}),
#  (1, 14, {'bond_weight': 0.2}),
#  (1, 15, {'bond_weight': 0.2}),
#  (1, 16, {'bond_weight': 0.2}),
#  (1, 17, {'bond_weight': 0.2}),
#  (1, 20, {'bond_weight': 0.2}),
#  (1, 21, {'bond_weight': 0.2}),
#  (1, 24, {'bond_weight': 0.2}),
#  (1, 25, {'bond_weight': 0.2}),
#  (1, 26, {'bond_weight': 0.2}),
#  (1, 28, {'bond_weight': 0.2}),
#  (1, 29, {'bond_weight': 0.2}),
#  (1, 30, {'bond_weight': 0.2}),
#  (1, 31, {'bond_weight': 0.2}),
#  (1, 32, {'bond_weight': 0.2}),
#  (1, 33, {'bond_weight': 0.2}),
#  (1, 35, {'bond_weight': 0.2}),
#  (1, 36, {'bond_weight': 0.2}),
#  (1, 37, {'bond_weight': 0.2}),
#  (1, 38, {'bond_weight': 0.2}),
#  (1, 39, {'bond_weight': 0.2}),
#  (1, 42, {'bond_weight': 0.2}),
#  (1, 43, {'bond_weight': 0.2}),
#  (1, 44, {'bond_weight': 0.2}),
#  (1, 45, {'bond_weight': 0.2}),
#  (1, 47, {'bond_weight': 0.2}),
#  (1, 64, {'bond_weight': 0.2}),
#  (1, 65, {'bond_weight': 0.2}),
#  (1, 74, {'bond_weight': 0.2}),
#  (1, 75, {'bond_weight': 0.2}),
#  (1, 76, {'bond_weight': 0.2}),
#  (1, 77, {'bond_weight': 0.2}),
#  (1, 78, {'bond_weight': 0.2}),
#  (1, 79, {'bond_weight': 0.2}),
#  (1, 80, {'bond_weight': 0.2}),
#  (1, 86, {'bond_weight': 0.2}),
#  (1, 87, {'bond_weight': 0.2}),
#  (1, 90, {'bond_weight': 0.2}),
#  (1, 91, {'bond_weight': 0.2}),
#  (1, 115, {'bond_weight': 0.2}),
#  (1, 116, {'bond_weight': 0.2}),
#  (1, 128, {'bond_weight': 0.2}),
#  (1, 129, {'bond_weight': 0.2}),
#  (1, 131, {'bond_weight': 0.2}),
#  (1, 132, {'bond_weight': 0.2}),
#  (1, 133, {'bond_weight': 0.2}),
#  (1, 135, {'bond_weight': 0.2}),
#  (1, 136, {'bond_weight': 0.2}),
#  (1, 433, {'bond_weight': 0.2}),
#  (1, 434, {'bond_weight': 0.2}),
#  (1, 435, {'bond_weight': 0.2}),
#  (1, 436, {'bond_weight': 0.2}),
#  (1, 437, {'bond_weight': 0.2}),
#  (1, 438, {'bond_weight': 0.2}),
#  (1, 450, {'bond_weight': 0.2}),
#  (1, 459, {'bond_weight': 0.2}),
#  (1, 460, {'bond_weight': 0.2}),
#  (1, 461, {'bond_weight': 0.2}),
#  (1, 469, {'bond_weight': 0.2}),
#  (1, 498, {'bond_weight': 0.2}),
#  (1, 499, {'bond_weight': 0.2}),
#  (1, 500, {'bond_weight': 0.2}),
#  (1, 508, {'bond_weight': 0.2}),
#  (2, 5, {'bond_weight': 0.2}),
#  (2, 7, {'bond_weight': 0.2}),
#  (2, 10, {'bond_weight': 0.2}),
#  (2, 12, {'bond_weight': 0.2}),
#  (2, 17, {'bond_weight': 0.2}),
#  (2, 18, {'bond_weight': 0.2}),
#  (2, 21, {'bond_weight': 0.2}),
#  (2, 22, {'bond_weight': 0.2}),
#  (2, 24, {'bond_weight': 0.2}),
#  (2, 26, {'bond_weight': 0.2}),
#  (2, 27, {'bond_weight': 0.2}),
#  (2, 29, {'bond_weight': 0.2}),
#  (2, 31, {'bond_weight': 0.2}),
#  (2, 33, {'bond_weight': 0.2}),
#  (2, 34, {'bond_weight': 0.2}),
#  (2, 36, {'bond_weight': 0.2}),
#  (2, 38, {'bond_weight': 0.2}),
#  (2, 40, {'bond_weight': 0.2}),
#  (2, 41, {'bond_weight': 0.2}),
#  (2, 43, {'bond_weight': 0.2}),
#  (2, 44, {'bond_weight': 0.2}),
#  (2, 45, {'bond_weight': 0.2}),
#  (2, 46, {'bond_weight': 0.2}),
#  (2, 48, {'bond_weight': 0.2}),
#  (2, 49, {'bond_weight': 0.2}),
#  (2, 50, {'bond_weight': 0.2}),
#  (2, 51, {'bond_weight': 0.2}),
#  (2, 52, {'bond_weight': 0.2}),
#  (2, 53, {'bond_weight': 0.2}),
#  (2, 54, {'bond_weight': 0.2}),
#  (2, 64, {'bond_weight': 0.2}),
#  (2, 65, {'bond_weight': 0.2}),
#  (2, 69, {'bond_weight': 0.2}),
#  (2, 70, {'bond_weight': 0.2}),
#  (2, 71, {'bond_weight': 0.2}),
#  (2, 72, {'bond_weight': 0.2}),
#  (2, 73, {'bond_weight': 0.2}),
#  (2, 74, {'bond_weight': 0.2}),
#  (2, 84, {'bond_weight': 0.2}),
#  (2, 85, {'bond_weight': 0.2}),
#  (2, 107, {'bond_weight': 0.2}),
#  (2, 110, {'bond_weight': 0.2}),
#  (2, 111, {'bond_weight': 0.2}),
#  (2, 112, {'bond_weight': 0.2}),
#  (2, 114, {'bond_weight': 0.2}),
#  (2, 115, {'bond_weight': 0.2}),
#  (2, 117, {'bond_weight': 0.2}),
#  (2, 118, {'bond_weight': 0.2}),
#  (2, 119, {'bond_weight': 0.2}),
#  (2, 120, {'bond_weight': 0.2}),
#  (2, 121, {'bond_weight': 0.2}),
#  (2, 122, {'bond_weight': 0.2}),
#  (2, 123, {'bond_weight': 0.2}),
#  (2, 124, {'bond_weight': 0.2}),
#  (2, 125, {'bond_weight': 0.2}),
#  (2, 126, {'bond_weight': 0.2}),
#  (2, 127, {'bond_weight': 0.2}),
#  (2, 128, {'bond_weight': 0.2}),
#  (2, 129, {'bond_weight': 0.2}),
#  (2, 130, {'bond_weight': 0.2}),
#  (2, 133, {'bond_weight': 0.2}),
#  (2, 135, {'bond_weight': 0.2}),
#  (2, 136, {'bond_weight': 0.2}),
#  (2, 274, {'bond_weight': 0.2}),
#  (2, 278, {'bond_weight': 0.2}),
#  (2, 279, {'bond_weight': 0.2}),
#  (2, 283, {'bond_weight': 0.2}),
#  (2, 285, {'bond_weight': 0.2}),
#  (2, 289, {'bond_weight': 0.2}),
#  (2, 290, {'bond_weight': 0.2}),
#  (2, 293, {'bond_weight': 0.2}),
#  (2, 294, {'bond_weight': 0.2}),
#  (2, 298, {'bond_weight': 0.2}),
#  (2, 299, {'bond_weight': 0.2}),
#  (2, 305, {'bond_weight': 0.2}),
#  (2, 306, {'bond_weight': 0.2}),
#  (2, 309, {'bond_weight': 0.2}),
#  (2, 312, {'bond_weight': 0.2}),
#  (2, 313, {'bond_weight': 0.2}),
#  (2, 317, {'bond_weight': 0.2}),
#  (2, 318, {'bond_weight': 0.2}),
#  (2, 338, {'bond_weight': 0.2}),
#  (2, 345, {'bond_weight': 0.2}),
#  (2, 346, {'bond_weight': 0.2}),
#  (2, 347, {'bond_weight': 0.2}),
#  (2, 348, {'bond_weight': 0.2}),
#  (2, 349, {'bond_weight': 0.2}),
#  (2, 350, {'bond_weight': 0.2}),
#  (2, 359, {'bond_weight': 0.2}),
#  (2, 360, {'bond_weight': 0.2}),
#  (2, 363, {'bond_weight': 0.2}),
#  (2, 364, {'bond_weight': 0.2}),
#  (2, 388, {'bond_weight': 0.2}),
#  (2, 404, {'bond_weight': 0.2}),
#  (2, 405, {'bond_weight': 0.2}),
#  (2, 426, {'bond_weight': 0.2}),
#  (2, 438, {'bond_weight': 0.2}),
#  (2, 439, {'bond_weight': 0.2}),
#  (2, 440, {'bond_weight': 0.2}),
#  (2, 441, {'bond_weight': 0.2}),
#  (2, 442, {'bond_weight': 0.2}),
#  (2, 443, {'bond_weight': 0.2}),
#  (2, 444, {'bond_weight': 0.2}),
#  (2, 445, {'bond_weight': 0.2}),
#  (2, 446, {'bond_weight': 0.2}),
#  (2, 447, {'bond_weight': 0.2}),
#  (2, 451, {'bond_weight': 0.2}),
#  (2, 452, {'bond_weight': 0.2}),
#  (2, 454, {'bond_weight': 0.2}),
#  (2, 455, {'bond_weight': 0.2}),
#  (2, 459, {'bond_weight': 0.2}),
#  (2, 472, {'bond_weight': 0.2}),
#  (2, 490, {'bond_weight': 0.2}),
#  (2, 491, {'bond_weight': 0.2}),
#  (2, 492, {'bond_weight': 0.2}),
#  (2, 493, {'bond_weight': 0.2}),
#  (2, 494, {'bond_weight': 0.2}),
#  (2, 496, {'bond_weight': 0.2}),
#  (2, 498, {'bond_weight': 0.2}),
#  (2, 503, {'bond_weight': 0.2}),
#  (3, 8, {'bond_weight': 0.2}),
#  (3, 10, {'bond_weight': 0.2}),
#  (3, 14, {'bond_weight': 0.2}),
#  (3, 18, {'bond_weight': 0.2}),
#  (3, 19, {'bond_weight': 0.2}),
#  (3, 22, {'bond_weight': 0.2}),
#  (3, 23, {'bond_weight': 0.2}),
#  (3, 27, {'bond_weight': 0.2}),
#  (3, 28, {'bond_weight': 0.2}),
#  (3, 34, {'bond_weight': 0.2}),
#  (3, 35, {'bond_weight': 0.2}),
#  (3, 40, {'bond_weight': 0.2}),
#  (3, 41, {'bond_weight': 0.2}),
#  (3, 42, {'bond_weight': 0.2}),
#  (3, 45, {'bond_weight': 0.2}),
#  (3, 46, {'bond_weight': 0.2}),
#  (3, 47, {'bond_weight': 0.2}),
#  (3, 64, {'bond_weight': 0.2}),
#  (3, 65, {'bond_weight': 0.2}),
#  (3, 66, {'bond_weight': 0.2}),
#  (3, 67, {'bond_weight': 0.2}),
#  (3, 68, {'bond_weight': 0.2}),
#  (3, 69, {'bond_weight': 0.2}),
#  (3, 70, {'bond_weight': 0.2}),
#  (3, 71, {'bond_weight': 0.2}),
#  (3, 81, {'bond_weight': 0.2}),
#  (3, 82, {'bond_weight': 0.2}),
#  (3, 83, {'bond_weight': 0.2}),
#  (3, 88, {'bond_weight': 0.2}),
#  (3, 89, {'bond_weight': 0.2}),
#  (3, 113, {'bond_weight': 0.2}),
#  (3, 114, {'bond_weight': 0.2}),
#  (3, 117, {'bond_weight': 0.2}),
#  (3, 437, {'bond_weight': 0.2}),
#  (3, 438, {'bond_weight': 0.2}),
#  (3, 439, {'bond_weight': 0.2}),
#  (3, 440, {'bond_weight': 0.2}),
#  (3, 441, {'bond_weight': 0.2}),
#  (3, 442, {'bond_weight': 0.2}),
#  (3, 443, {'bond_weight': 0.2}),
#  (3, 444, {'bond_weight': 0.2}),
#  (3, 445, {'bond_weight': 0.2}),
#  (3, 450, {'bond_weight': 0.2}),
#  (3, 451, {'bond_weight': 0.2}),
#  (3, 452, {'bond_weight': 0.2}),
#  (3, 454, {'bond_weight': 0.2}),
#  (3, 455, {'bond_weight': 0.2}),
#  (3, 456, {'bond_weight': 0.2}),
#  (3, 457, {'bond_weight': 0.2}),
#  (3, 458, {'bond_weight': 0.2}),
#  (3, 459, {'bond_weight': 0.2}),
#  (3, 460, {'bond_weight': 0.2}),
#  (3, 461, {'bond_weight': 0.2}),
#  (3, 492, {'bond_weight': 0.2}),
#  (3, 493, {'bond_weight': 0.2}),
#  (3, 494, {'bond_weight': 0.2}),
#  (3, 496, {'bond_weight': 0.2}),
#  (3, 497, {'bond_weight': 0.2}),
#  (3, 498, {'bond_weight': 0.2}),
#  (4, 5, {'bond_weight': 0.2}),
#  (4, 6, {'bond_weight': 0.2}),
#  (4, 9, {'bond_weight': 0.2}),
#  (4, 10, {'bond_weight': 0.2}),
#  (4, 11, {'bond_weight': 0.2}),
#  (4, 12, {'bond_weight': 0.2}),
#  (4, 13, {'bond_weight': 0.2}),
#  (4, 14, {'bond_weight': 0.2}),
#  (4, 15, {'bond_weight': 0.2}),
#  (4, 16, {'bond_weight': 0.2}),
#  (4, 17, {'bond_weight': 0.2}),
#  (4, 19, {'bond_weight': 0.2}),
#  (4, 20, {'bond_weight': 0.2}),
#  (4, 23, {'bond_weight': 0.2}),
#  (4, 25, {'bond_weight': 0.2}),
#  (4, 28, {'bond_weight': 0.2}),
#  (4, 30, {'bond_weight': 0.2}),
#  (4, 32, {'bond_weight': 0.2}),
#  (4, 35, {'bond_weight': 0.2}),
#  (4, 36, {'bond_weight': 0.2}),
#  (4, 37, {'bond_weight': 0.2}),
#  (4, 39, {'bond_weight': 0.2}),
#  (4, 42, {'bond_weight': 0.2}),
#  (4, 44, {'bond_weight': 0.2}),
#  (4, 46, {'bond_weight': 0.2}),
#  (4, 47, {'bond_weight': 0.2}),
#  (4, 64, {'bond_weight': 0.2}),
#  (4, 65, {'bond_weight': 0.2}),
#  (4, 66, {'bond_weight': 0.2}),
#  (4, 67, {'bond_weight': 0.2}),
#  (4, 68, {'bond_weight': 0.2}),
#  (4, 75, {'bond_weight': 0.2}),
#  (4, 77, {'bond_weight': 0.2}),
#  (4, 78, {'bond_weight': 0.2}),
#  (4, 79, {'bond_weight': 0.2}),
#  (4, 80, {'bond_weight': 0.2}),
#  (4, 82, {'bond_weight': 0.2}),
#  (4, 86, {'bond_weight': 0.2}),
#  (4, 87, {'bond_weight': 0.2}),
#  (4, 90, {'bond_weight': 0.2}),
#  (4, 91, {'bond_weight': 0.2}),
#  (4, 113, {'bond_weight': 0.2}),
#  (4, 116, {'bond_weight': 0.2}),
#  (4, 131, {'bond_weight': 0.2}),
#  (4, 132, {'bond_weight': 0.2}),
#  (4, 434, {'bond_weight': 0.2}),
#  (4, 435, {'bond_weight': 0.2}),
#  (4, 436, {'bond_weight': 0.2}),
#  (4, 437, {'bond_weight': 0.2}),
#  (4, 450, {'bond_weight': 0.2}),
#  (4, 459, {'bond_weight': 0.2}),
#  (4, 460, {'bond_weight': 0.2}),
#  (4, 461, {'bond_weight': 0.2}),
#  (4, 499, {'bond_weight': 0.2}),
#  (4, 508, {'bond_weight': 0.2}),
#  (5, 6, {'bond_weight': 0.2}),
#  (5, 9, {'bond_weight': 0.2}),
#  (5, 10, {'bond_weight': 0.2}),
#  (5, 11, {'bond_weight': 0.2}),
#  (5, 12, {'bond_weight': 0.2}),
#  (5, 13, {'bond_weight': 0.2}),
#  (5, 14, {'bond_weight': 0.2}),
#  (5, 15, {'bond_weight': 0.2}),
#  (5, 16, {'bond_weight': 0.2}),
#  (5, 17, {'bond_weight': 0.2}),
#  (5, 18, {'bond_weight': 0.2}),
#  (5, 19, {'bond_weight': 0.2}),
#  (5, 20, {'bond_weight': 0.2}),
#  (5, 21, {'bond_weight': 0.2}),
#  (5, 23, {'bond_weight': 0.2}),
#  (5, 24, {'bond_weight': 0.2}),
#  (5, 25, {'bond_weight': 0.2}),
#  (5, 26, {'bond_weight': 0.2}),
#  (5, 27, {'bond_weight': 0.2}),
#  (5, 28, {'bond_weight': 0.2}),
#  (5, 29, {'bond_weight': 0.2}),
#  (5, 30, {'bond_weight': 0.2}),
#  (5, 31, {'bond_weight': 0.2}),
#  (5, 32, {'bond_weight': 0.2}),
#  (5, 33, {'bond_weight': 0.2}),
#  (5, 34, {'bond_weight': 0.2}),
#  (5, 35, {'bond_weight': 0.2}),
#  (5, 36, {'bond_weight': 0.2}),
#  (5, 37, {'bond_weight': 0.2}),
#  (5, 38, {'bond_weight': 0.2}),
#  (5, 39, {'bond_weight': 0.2}),
#  (5, 40, {'bond_weight': 0.2}),
#  (5, 41, {'bond_weight': 0.2}),
#  (5, 42, {'bond_weight': 0.2}),
#  (5, 43, {'bond_weight': 0.2}),
#  (5, 44, {'bond_weight': 0.2}),
#  (5, 45, {'bond_weight': 0.2}),
#  (5, 46, {'bond_weight': 0.2}),
#  (5, 47, {'bond_weight': 0.2}),
#  (5, 48, {'bond_weight': 0.2}),
#  (5, 49, {'bond_weight': 0.2}),
#  (5, 64, {'bond_weight': 0.2}),
#  (5, 65, {'bond_weight': 0.2}),
#  (5, 66, {'bond_weight': 0.2}),
#  (5, 67, {'bond_weight': 0.2}),
#  (5, 68, {'bond_weight': 0.2}),
#  (5, 72, {'bond_weight': 0.2}),
#  (5, 73, {'bond_weight': 0.2}),
#  (5, 74, {'bond_weight': 0.2}),
#  (5, 75, {'bond_weight': 0.2}),
#  (5, 76, {'bond_weight': 0.2}),
#  (5, 77, {'bond_weight': 0.2}),
#  (5, 78, {'bond_weight': 0.2}),
#  (5, 79, {'bond_weight': 0.2}),
#  (5, 80, {'bond_weight': 0.2}),
#  (5, 82, {'bond_weight': 0.2}),
#  (5, 85, {'bond_weight': 0.2}),
#  (5, 86, {'bond_weight': 0.2}),
#  (5, 87, {'bond_weight': 0.2}),
#  (5, 90, {'bond_weight': 0.2}),
#  (5, 91, {'bond_weight': 0.2}),
#  (5, 113, {'bond_weight': 0.2}),
#  (5, 114, {'bond_weight': 0.2}),
#  (5, 115, {'bond_weight': 0.2}),
#  (5, 116, {'bond_weight': 0.2}),
#  (5, 117, {'bond_weight': 0.2}),
#  (5, 124, {'bond_weight': 0.2}),
#  (5, 125, {'bond_weight': 0.2}),
#  (5, 128, {'bond_weight': 0.2}),
#  (5, 129, {'bond_weight': 0.2}),
#  (5, 131, {'bond_weight': 0.2}),
#  (5, 132, {'bond_weight': 0.2}),
#  (5, 133, {'bond_weight': 0.2}),
#  (5, 135, {'bond_weight': 0.2}),
#  (5, 136, {'bond_weight': 0.2}),
#  (5, 434, {'bond_weight': 0.2}),
#  (5, 436, {'bond_weight': 0.2}),
#  (5, 437, {'bond_weight': 0.2}),
#  (5, 438, {'bond_weight': 0.2}),
#  (5, 439, {'bond_weight': 0.2}),
#  (5, 440, {'bond_weight': 0.2}),
#  (5, 450, {'bond_weight': 0.2}),
#  (5, 459, {'bond_weight': 0.2}),
#  (5, 460, {'bond_weight': 0.2}),
#  (5, 461, {'bond_weight': 0.2}),
#  (5, 469, {'bond_weight': 0.2}),
#  (5, 494, {'bond_weight': 0.2}),
#  (5, 496, {'bond_weight': 0.2}),
#  (5, 498, {'bond_weight': 0.2}),
#  (5, 499, {'bond_weight': 0.2}),
#  (5, 508, {'bond_weight': 0.2}),
#  (6, 9, {'bond_weight': 0.2}),
#  (6, 10, {'bond_weight': 0.2}),
#  (6, 11, {'bond_weight': 0.2}),
#  (6, 12, {'bond_weight': 0.2}),
#  (6, 13, {'bond_weight': 0.2}),
#  (6, 14, {'bond_weight': 0.2}),
#  (6, 15, {'bond_weight': 0.2}),
#  (6, 16, {'bond_weight': 0.2}),
#  (6, 17, {'bond_weight': 0.2}),
#  (6, 19, {'bond_weight': 0.2}),
#  (6, 20, {'bond_weight': 0.2}),
#  (6, 21, {'bond_weight': 0.2}),
#  (6, 24, {'bond_weight': 0.2}),
#  (6, 25, {'bond_weight': 0.2}),
#  (6, 26, {'bond_weight': 0.2}),
#  (6, 28, {'bond_weight': 0.2}),
#  (6, 29, {'bond_weight': 0.2}),
#  (6, 30, {'bond_weight': 0.2}),
#  (6, 31, {'bond_weight': 0.2}),
#  (6, 32, {'bond_weight': 0.2}),
#  (6, 33, {'bond_weight': 0.2}),
#  (6, 35, {'bond_weight': 0.2}),
#  (6, 36, {'bond_weight': 0.2}),
#  (6, 37, {'bond_weight': 0.2}),
#  (6, 38, {'bond_weight': 0.2}),
#  (6, 39, {'bond_weight': 0.2}),
#  (6, 40, {'bond_weight': 0.2}),
#  (6, 42, {'bond_weight': 0.2}),
#  (6, 43, {'bond_weight': 0.2}),
#  (6, 44, {'bond_weight': 0.2}),
#  (6, 45, {'bond_weight': 0.2}),
#  (6, 46, {'bond_weight': 0.2}),
#  (6, 47, {'bond_weight': 0.2}),
#  (6, 48, {'bond_weight': 0.2}),
#  (6, 49, {'bond_weight': 0.2}),
#  (6, 64, {'bond_weight': 0.2}),
#  (6, 65, {'bond_weight': 0.2}),
#  (6, 72, {'bond_weight': 0.2}),
#  (6, 74, {'bond_weight': 0.2}),
#  (6, 75, {'bond_weight': 0.2}),
#  (6, 76, {'bond_weight': 0.2}),
#  (6, 77, {'bond_weight': 0.2}),
#  (6, 78, {'bond_weight': 0.2}),
#  (6, 79, {'bond_weight': 0.2}),
#  (6, 80, {'bond_weight': 0.2}),
#  (6, 86, {'bond_weight': 0.2}),
#  (6, 87, {'bond_weight': 0.2}),
#  (6, 90, {'bond_weight': 0.2}),
#  (6, 91, {'bond_weight': 0.2}),
#  (6, 115, {'bond_weight': 0.2}),
#  (6, 116, {'bond_weight': 0.2}),
#  (6, 124, {'bond_weight': 0.2}),
#  (6, 125, {'bond_weight': 0.2}),
#  (6, 128, {'bond_weight': 0.2}),
#  (6, 129, {'bond_weight': 0.2}),
#  (6, 130, {'bond_weight': 0.2}),
#  (6, 131, {'bond_weight': 0.2}),
#  (6, 132, {'bond_weight': 0.2}),
#  (6, 133, {'bond_weight': 0.2}),
#  (6, 135, {'bond_weight': 0.2}),
#  (6, 136, {'bond_weight': 0.2}),
#  (6, 392, {'bond_weight': 0.2}),
#  (6, 432, {'bond_weight': 0.2}),
#  (6, 433, {'bond_weight': 0.2}),
#  (6, 434, {'bond_weight': 0.2}),
#  (6, 435, {'bond_weight': 0.2}),
#  (6, 436, {'bond_weight': 0.2}),
#  (6, 437, {'bond_weight': 0.2}),
#  (6, 438, {'bond_weight': 0.2}),
#  (6, 439, {'bond_weight': 0.2}),
#  (6, 440, {'bond_weight': 0.2}),
#  (6, 448, {'bond_weight': 0.2}),
#  (6, 449, {'bond_weight': 0.2}),
#  (6, 450, {'bond_weight': 0.2}),
#  (6, 459, {'bond_weight': 0.2}),
#  (6, 460, {'bond_weight': 0.2}),
#  (6, 461, {'bond_weight': 0.2}),
#  (6, 462, {'bond_weight': 0.2}),
#  (6, 463, {'bond_weight': 0.2}),
#  (6, 464, {'bond_weight': 0.2}),
#  (6, 466, {'bond_weight': 0.2}),
#  (6, 468, {'bond_weight': 0.2}),
#  (6, 469, {'bond_weight': 0.2}),
#  (6, 496, {'bond_weight': 0.2}),
#  (6, 498, {'bond_weight': 0.2}),
#  (6, 499, {'bond_weight': 0.2}),
#  (6, 500, {'bond_weight': 0.2}),
#  (6, 508, {'bond_weight': 0.2}),
#  (7, 10, {'bond_weight': 0.2}),
#  (7, 17, {'bond_weight': 0.2}),
#  (7, 18, {'bond_weight': 0.2}),
#  (7, 21, {'bond_weight': 0.2}),
#  (7, 22, {'bond_weight': 0.2}),
#  (7, 24, {'bond_weight': 0.2}),
#  (7, 26, {'bond_weight': 0.2}),
#  (7, 27, {'bond_weight': 0.2}),
#  (7, 31, {'bond_weight': 0.2}),
#  (7, 33, {'bond_weight': 0.2}),
#  (7, 34, {'bond_weight': 0.2}),
#  (7, 38, {'bond_weight': 0.2}),
#  (7, 40, {'bond_weight': 0.2}),
#  (7, 43, {'bond_weight': 0.2}),
#  (7, 44, {'bond_weight': 0.2}),
#  (7, 45, {'bond_weight': 0.2}),
#  (7, 48, {'bond_weight': 0.2}),
#  (7, 49, {'bond_weight': 0.2}),
#  (7, 50, {'bond_weight': 0.2}),
#  (7, 51, {'bond_weight': 0.2}),
#  (7, 52, {'bond_weight': 0.2}),
#  (7, 53, {'bond_weight': 0.2}),
#  (7, 64, {'bond_weight': 0.2}),
#  (7, 65, {'bond_weight': 0.2}),
#  (7, 69, {'bond_weight': 0.2}),
#  (7, 70, {'bond_weight': 0.2}),
#  (7, 71, {'bond_weight': 0.2}),
#  (7, 72, {'bond_weight': 0.2}),
#  (7, 73, {'bond_weight': 0.2}),
#  (7, 74, {'bond_weight': 0.2}),
#  (7, 84, {'bond_weight': 0.2}),
#  (7, 85, {'bond_weight': 0.2}),
#  (7, 111, {'bond_weight': 0.2}),
#  (7, 112, {'bond_weight': 0.2}),
#  (7, 114, {'bond_weight': 0.2}),
#  (7, 115, {'bond_weight': 0.2}),
#  (7, 117, {'bond_weight': 0.2}),
#  (7, 119, {'bond_weight': 0.2}),
#  (7, 120, {'bond_weight': 0.2}),
#  (7, 121, {'bond_weight': 0.2}),
#  (7, 122, {'bond_weight': 0.2}),
#  (7, 123, {'bond_weight': 0.2}),
#  (7, 124, {'bond_weight': 0.2}),
#  (7, 125, {'bond_weight': 0.2}),
#  (7, 126, {'bond_weight': 0.2}),
#  (7, 127, {'bond_weight': 0.2}),
#  (7, 128, {'bond_weight': 0.2}),
#  (7, 130, {'bond_weight': 0.2}),
#  (7, 133, {'bond_weight': 0.2}),
#  (7, 135, {'bond_weight': 0.2}),
#  (7, 136, {'bond_weight': 0.2}),
#  (7, 147, {'bond_weight': 0.2}),
#  (7, 159, {'bond_weight': 0.2}),
#  (7, 202, {'bond_weight': 0.2}),
#  (7, 204, {'bond_weight': 0.2}),
#  (7, 274, {'bond_weight': 0.2}),
#  (7, 278, {'bond_weight': 0.2}),
#  (7, 279, {'bond_weight': 0.2}),
#  (7, 282, {'bond_weight': 0.2}),
#  (7, 283, {'bond_weight': 0.2}),
#  (7, 285, {'bond_weight': 0.2}),
#  (7, 287, {'bond_weight': 0.2}),
#  (7, 289, {'bond_weight': 0.2}),
#  (7, 290, {'bond_weight': 0.2}),
#  (7, 291, {'bond_weight': 0.2}),
#  (7, 293, {'bond_weight': 0.2}),
#  (7, 294, {'bond_weight': 0.2}),
#  (7, 298, {'bond_weight': 0.2}),
#  (7, 299, {'bond_weight': 0.2}),
#  (7, 302, {'bond_weight': 0.2}),
#  (7, 305, {'bond_weight': 0.2}),
#  (7, 306, {'bond_weight': 0.2}),
#  (7, 309, {'bond_weight': 0.2}),
#  (7, 312, {'bond_weight': 0.2}),
#  (7, 313, {'bond_weight': 0.2}),
#  (7, 317, {'bond_weight': 0.2}),
#  (7, 318, {'bond_weight': 0.2}),
#  (7, 320, {'bond_weight': 0.2}),
#  (7, 337, {'bond_weight': 0.2}),
#  (7, 338, {'bond_weight': 0.2}),
#  (7, 345, {'bond_weight': 0.2}),
#  (7, 346, {'bond_weight': 0.2}),
#  (7, 347, {'bond_weight': 0.2}),
#  (7, 348, {'bond_weight': 0.2}),
#  (7, 349, {'bond_weight': 0.2}),
#  (7, 350, {'bond_weight': 0.2}),
#  (7, 359, {'bond_weight': 0.2}),
#  (7, 360, {'bond_weight': 0.2}),
#  (7, 363, {'bond_weight': 0.2}),
#  (7, 364, {'bond_weight': 0.2}),
#  (7, 388, {'bond_weight': 0.2}),
#  (7, 389, {'bond_weight': 0.2}),
#  (7, 404, {'bond_weight': 0.2}),
#  (7, 405, {'bond_weight': 0.2}),
#  (7, 425, {'bond_weight': 0.2}),
#  (7, 426, {'bond_weight': 0.2}),
#  (7, 431, {'bond_weight': 0.2}),
#  (7, 440, {'bond_weight': 0.2}),
#  (7, 441, {'bond_weight': 0.2}),
#  (7, 442, {'bond_weight': 0.2}),
#  (7, 443, {'bond_weight': 0.2}),
#  (7, 444, {'bond_weight': 0.2}),
#  (7, 445, {'bond_weight': 0.2}),
#  (7, 446, {'bond_weight': 0.2}),
#  (7, 447, {'bond_weight': 0.2}),
#  (7, 452, {'bond_weight': 0.2}),
#  (7, 471, {'bond_weight': 0.2}),
#  (7, 472, {'bond_weight': 0.2}),
#  (7, 490, {'bond_weight': 0.2}),
#  (7, 491, {'bond_weight': 0.2}),
#  (7, 492, {'bond_weight': 0.2}),
#  (7, 493, {'bond_weight': 0.2}),
#  (7, 494, {'bond_weight': 0.2}),
#  (7, 496, {'bond_weight': 0.2}),
#  (7, 503, {'bond_weight': 0.2}),
#  (8, 10, {'bond_weight': 0.2}),
#  (8, 14, {'bond_weight': 0.2}),
#  (8, 18, {'bond_weight': 0.2}),
#  (8, 19, {'bond_weight': 0.2}),
#  (8, 22, {'bond_weight': 0.2}),
#  (8, 23, {'bond_weight': 0.2}),
#  (8, 27, {'bond_weight': 0.2}),
#  (8, 28, {'bond_weight': 0.2}),
#  (8, 34, {'bond_weight': 0.2}),
#  (8, 35, {'bond_weight': 0.2}),
#  (8, 41, {'bond_weight': 0.2}),
#  (8, 42, {'bond_weight': 0.2}),
#  (8, 45, {'bond_weight': 0.2}),
#  (8, 46, {'bond_weight': 0.2}),
#  (8, 47, {'bond_weight': 0.2}),
#  (8, 64, {'bond_weight': 0.2}),
#  (8, 65, {'bond_weight': 0.2}),
#  (8, 66, {'bond_weight': 0.2}),
#  (8, 67, {'bond_weight': 0.2}),
#  (8, 68, {'bond_weight': 0.2}),
#  (8, 69, {'bond_weight': 0.2}),
#  (8, 70, {'bond_weight': 0.2}),
#  (8, 71, {'bond_weight': 0.2}),
#  (8, 81, {'bond_weight': 0.2}),
#  (8, 82, {'bond_weight': 0.2}),
#  (8, 83, {'bond_weight': 0.2}),
#  (8, 88, {'bond_weight': 0.2}),
#  (8, 89, {'bond_weight': 0.2}),
#  (8, 103, {'bond_weight': 0.2}),
#  (8, 113, {'bond_weight': 0.2}),
#  (8, 114, {'bond_weight': 0.2}),
#  (8, 432, {'bond_weight': 0.2}),
#  (8, 436, {'bond_weight': 0.2}),
#  (8, 437, {'bond_weight': 0.2}),
#  (8, 438, {'bond_weight': 0.2}),
#  (8, 439, {'bond_weight': 0.2}),
#  (8, 440, {'bond_weight': 0.2}),
#  (8, 441, {'bond_weight': 0.2}),
#  (8, 442, {'bond_weight': 0.2}),
#  (8, 443, {'bond_weight': 0.2}),
#  (8, 444, {'bond_weight': 0.2}),
#  (8, 448, {'bond_weight': 0.2}),
#  (8, 450, {'bond_weight': 0.2}),
#  (8, 451, {'bond_weight': 0.2}),
#  (8, 455, {'bond_weight': 0.2}),
#  (8, 456, {'bond_weight': 0.2}),
#  (8, 457, {'bond_weight': 0.2}),
#  (8, 458, {'bond_weight': 0.2}),
#  (8, 459, {'bond_weight': 0.2}),
#  (8, 460, {'bond_weight': 0.2}),
#  (8, 461, {'bond_weight': 0.2}),
#  (8, 466, {'bond_weight': 0.2}),
#  (8, 467, {'bond_weight': 0.2}),
#  (8, 492, {'bond_weight': 0.2}),
#  (8, 493, {'bond_weight': 0.2}),
#  (8, 494, {'bond_weight': 0.2}),
#  (8, 496, {'bond_weight': 0.2}),
#  (8, 497, {'bond_weight': 0.2}),
#  (8, 498, {'bond_weight': 0.2}),
#  (8, 499, {'bond_weight': 0.2}),
#  (9, 10, {'bond_weight': 0.2}),
#  (9, 11, {'bond_weight': 0.2}),
#  (9, 12, {'bond_weight': 0.2}),
#  (9, 13, {'bond_weight': 0.2}),
#  (9, 14, {'bond_weight': 0.2}),
#  (9, 15, {'bond_weight': 0.2}),
#  (9, 16, {'bond_weight': 0.2}),
#  (9, 17, {'bond_weight': 0.2}),
#  (9, 19, {'bond_weight': 0.2}),
#  (9, 20, {'bond_weight': 0.2}),
#  (9, 23, {'bond_weight': 0.2}),
#  (9, 24, {'bond_weight': 0.2}),
#  (9, 25, {'bond_weight': 0.2}),
#  (9, 26, {'bond_weight': 0.2}),
#  (9, 28, {'bond_weight': 0.2}),
#  (9, 29, {'bond_weight': 0.2}),
#  (9, 30, {'bond_weight': 0.2}),
#  (9, 32, {'bond_weight': 0.2}),
#  (9, 35, {'bond_weight': 0.2}),
#  (9, 36, {'bond_weight': 0.2}),
#  (9, 37, {'bond_weight': 0.2}),
#  (9, 39, {'bond_weight': 0.2}),
#  (9, 42, {'bond_weight': 0.2}),
#  (9, 44, {'bond_weight': 0.2}),
#  (9, 46, {'bond_weight': 0.2}),
#  (9, 47, {'bond_weight': 0.2}),
#  (9, 64, {'bond_weight': 0.2}),
#  (9, 65, {'bond_weight': 0.2}),
#  (9, 66, {'bond_weight': 0.2}),
#  (9, 67, {'bond_weight': 0.2}),
#  (9, 68, {'bond_weight': 0.2}),
#  (9, 75, {'bond_weight': 0.2}),
#  (9, 76, {'bond_weight': 0.2}),
#  (9, 77, {'bond_weight': 0.2}),
#  (9, 78, {'bond_weight': 0.2}),
#  (9, 79, {'bond_weight': 0.2}),
#  (9, 80, {'bond_weight': 0.2}),
#  (9, 86, {'bond_weight': 0.2}),
#  (9, 87, {'bond_weight': 0.2}),
#  (9, 90, {'bond_weight': 0.2}),
#  (9, 91, {'bond_weight': 0.2}),
#  (9, 113, {'bond_weight': 0.2}),
#  (9, 115, {'bond_weight': 0.2}),
#  (9, 116, {'bond_weight': 0.2}),
#  (9, 131, {'bond_weight': 0.2}),
#  (9, 132, {'bond_weight': 0.2}),
#  (9, 135, {'bond_weight': 0.2}),
#  (9, 136, {'bond_weight': 0.2}),
#  (9, 434, {'bond_weight': 0.2}),
#  (9, 435, {'bond_weight': 0.2}),
#  (9, 436, {'bond_weight': 0.2}),
#  (9, 437, {'bond_weight': 0.2}),
#  (9, 438, {'bond_weight': 0.2}),
#  (9, 450, {'bond_weight': 0.2}),
#  (9, 459, {'bond_weight': 0.2}),
#  (9, 460, {'bond_weight': 0.2}),
#  (9, 461, {'bond_weight': 0.2}),
#  (9, 498, {'bond_weight': 0.2}),
#  (9, 499, {'bond_weight': 0.2}),
#  (9, 500, {'bond_weight': 0.2}),
#  (9, 508, {'bond_weight': 0.2}),
#  (10, 12, {'bond_weight': 0.2}),
#  (10, 14, {'bond_weight': 0.2}),
#  (10, 16, {'bond_weight': 0.2}),
#  (10, 17, {'bond_weight': 0.2}),
#  (10, 18, {'bond_weight': 0.2}),
#  (10, 19, {'bond_weight': 0.2}),
#  (10, 20, {'bond_weight': 0.2}),
#  (10, 21, {'bond_weight': 0.2}),
#  (10, 22, {'bond_weight': 0.2}),
#  (10, 24, {'bond_weight': 0.2}),
#  (10, 25, {'bond_weight': 0.2}),
#  (10, 26, {'bond_weight': 0.2}),
#  (10, 27, {'bond_weight': 0.2}),
#  (10, 28, {'bond_weight': 0.2}),
#  (10, 29, {'bond_weight': 0.2}),
#  (10, 31, {'bond_weight': 0.2}),
#  (10, 32, {'bond_weight': 0.2}),
#  (10, 33, {'bond_weight': 0.2}),
#  (10, 34, {'bond_weight': 0.2}),
#  (10, 35, {'bond_weight': 0.2}),
#  (10, 36, {'bond_weight': 0.2}),
#  (10, 38, {'bond_weight': 0.2}),
#  (10, 39, {'bond_weight': 0.2}),
#  (10, 40, {'bond_weight': 0.2}),
#  (10, 41, {'bond_weight': 0.2}),
#  (10, 42, {'bond_weight': 0.2}),
#  (10, 43, {'bond_weight': 0.2}),
#  (10, 44, {'bond_weight': 0.2}),
#  (10, 45, {'bond_weight': 0.2}),
#  (10, 46, {'bond_weight': 0.2}),
#  (10, 47, {'bond_weight': 0.2}),
#  (10, 48, {'bond_weight': 0.2}),
#  (10, 49, {'bond_weight': 0.2}),
#  (10, 50, {'bond_weight': 0.2}),
#  (10, 51, {'bond_weight': 0.2}),
#  (10, 64, {'bond_weight': 0.2}),
#  (10, 65, {'bond_weight': 0.2}),
#  (10, 69, {'bond_weight': 0.2}),
#  (10, 70, {'bond_weight': 0.2}),
#  (10, 71, {'bond_weight': 0.2}),
#  (10, 72, {'bond_weight': 0.2}),
#  (10, 73, {'bond_weight': 0.2}),
#  (10, 74, {'bond_weight': 0.2}),
#  (10, 75, {'bond_weight': 0.2}),
#  (10, 76, {'bond_weight': 0.2}),
#  (10, 77, {'bond_weight': 0.2}),
#  (10, 81, {'bond_weight': 0.2}),
#  (10, 82, {'bond_weight': 0.2}),
#  (10, 84, {'bond_weight': 0.2}),
#  (10, 85, {'bond_weight': 0.2}),
#  (10, 86, {'bond_weight': 0.2}),
#  (10, 87, {'bond_weight': 0.2}),
#  (10, 88, {'bond_weight': 0.2}),
#  (10, 89, {'bond_weight': 0.2}),
#  (10, 90, {'bond_weight': 0.2}),
#  (10, 91, {'bond_weight': 0.2}),
#  (10, 111, {'bond_weight': 0.2}),
#  (10, 113, {'bond_weight': 0.2}),
#  (10, 114, {'bond_weight': 0.2}),
#  (10, 115, {'bond_weight': 0.2}),
#  (10, 116, {'bond_weight': 0.2}),
#  (10, 117, {'bond_weight': 0.2}),
#  (10, 120, {'bond_weight': 0.2}),
#  (10, 121, {'bond_weight': 0.2}),
#  (10, 122, {'bond_weight': 0.2}),
#  (10, 123, {'bond_weight': 0.2}),
#  (10, 124, {'bond_weight': 0.2}),
#  (10, 125, {'bond_weight': 0.2}),
#  (10, 126, {'bond_weight': 0.2}),
#  (10, 127, {'bond_weight': 0.2}),
#  (10, 128, {'bond_weight': 0.2}),
#  (10, 129, {'bond_weight': 0.2}),
#  (10, 130, {'bond_weight': 0.2}),
#  (10, 131, {'bond_weight': 0.2}),
#  (10, 132, {'bond_weight': 0.2}),
#  (10, 133, {'bond_weight': 0.2}),
#  (10, 135, {'bond_weight': 0.2}),
#  (10, 136, {'bond_weight': 0.2}),
#  (10, 279, {'bond_weight': 0.2}),
#  (10, 359, {'bond_weight': 0.2}),
#  (10, 360, {'bond_weight': 0.2}),
#  (10, 364, {'bond_weight': 0.2}),
#  (10, 404, {'bond_weight': 0.2}),
#  (10, 432, {'bond_weight': 0.2}),
#  (10, 436, {'bond_weight': 0.2}),
#  (10, 437, {'bond_weight': 0.2}),
#  (10, 438, {'bond_weight': 0.2}),
#  (10, 439, {'bond_weight': 0.2}),
#  (10, 440, {'bond_weight': 0.2}),
#  (10, 441, {'bond_weight': 0.2}),
#  (10, 442, {'bond_weight': 0.2}),
#  (10, 443, {'bond_weight': 0.2}),
#  (10, 444, {'bond_weight': 0.2}),
#  (10, 449, {'bond_weight': 0.2}),
#  (10, 450, {'bond_weight': 0.2}),
#  (10, 451, {'bond_weight': 0.2}),
#  (10, 459, {'bond_weight': 0.2}),
#  (10, 460, {'bond_weight': 0.2}),
#  (10, 461, {'bond_weight': 0.2}),
#  (10, 463, {'bond_weight': 0.2}),
#  (10, 464, {'bond_weight': 0.2}),
#  (10, 469, {'bond_weight': 0.2}),
#  (10, 491, {'bond_weight': 0.2}),
#  (10, 492, {'bond_weight': 0.2}),
#  (10, 493, {'bond_weight': 0.2}),
#  (10, 494, {'bond_weight': 0.2}),
#  (10, 496, {'bond_weight': 0.2}),
#  (10, 497, {'bond_weight': 0.2}),
#  (10, 498, {'bond_weight': 0.2}),
#  (10, 499, {'bond_weight': 0.2}),
#  (11, 13, {'bond_weight': 0.2}),
#  (11, 14, {'bond_weight': 0.2}),
#  (11, 15, {'bond_weight': 0.2}),
#  (11, 16, {'bond_weight': 0.2}),
#  (11, 19, {'bond_weight': 0.2}),
#  (11, 23, {'bond_weight': 0.2}),
#  (11, 25, {'bond_weight': 0.2}),
#  (11, 28, {'bond_weight': 0.2}),
#  (11, 30, {'bond_weight': 0.2}),
#  (11, 32, {'bond_weight': 0.2}),
#  (11, 35, {'bond_weight': 0.2}),
#  (11, 37, {'bond_weight': 0.2}),
#  (11, 39, {'bond_weight': 0.2}),
#  (11, 42, {'bond_weight': 0.2}),
#  (11, 44, {'bond_weight': 0.2}),
#  (11, 46, {'bond_weight': 0.2}),
#  (11, 47, {'bond_weight': 0.2}),
#  (11, 65, {'bond_weight': 0.2}),
#  (11, 66, {'bond_weight': 0.2}),
#  (11, 67, {'bond_weight': 0.2}),
#  (11, 68, {'bond_weight': 0.2}),
#  (11, 77, {'bond_weight': 0.2}),
#  (11, 78, {'bond_weight': 0.2}),
#  (11, 79, {'bond_weight': 0.2}),
#  (11, 80, {'bond_weight': 0.2}),
#  (11, 86, {'bond_weight': 0.2}),
#  (11, 87, {'bond_weight': 0.2}),
#  (11, 90, {'bond_weight': 0.2}),
#  (11, 91, {'bond_weight': 0.2}),
#  (11, 113, {'bond_weight': 0.2}),
#  (11, 116, {'bond_weight': 0.2}),
#  (11, 132, {'bond_weight': 0.2}),
#  (11, 436, {'bond_weight': 0.2}),
#  (11, 437, {'bond_weight': 0.2}),
#  (11, 450, {'bond_weight': 0.2}),
#  (11, 459, {'bond_weight': 0.2}),
#  (11, 460, {'bond_weight': 0.2}),
#  (11, 461, {'bond_weight': 0.2}),
#  (11, 499, {'bond_weight': 0.2}),
#  (12, 13, {'bond_weight': 0.2}),
#  (12, 14, {'bond_weight': 0.2}),
#  (12, 15, {'bond_weight': 0.2}),
#  (12, 16, {'bond_weight': 0.2}),
#  (12, 17, {'bond_weight': 0.2}),
#  (12, 18, {'bond_weight': 0.2}),
#  (12, 20, {'bond_weight': 0.2}),
#  (12, 21, {'bond_weight': 0.2}),
#  (12, 24, {'bond_weight': 0.2}),
#  (12, 25, {'bond_weight': 0.2}),
#  (12, 26, {'bond_weight': 0.2}),
#  (12, 27, {'bond_weight': 0.2}),
#  (12, 28, {'bond_weight': 0.2}),
#  (12, 29, {'bond_weight': 0.2}),
#  (12, 30, {'bond_weight': 0.2}),
#  (12, 31, {'bond_weight': 0.2}),
#  (12, 32, {'bond_weight': 0.2}),
#  (12, 33, {'bond_weight': 0.2}),
#  (12, 36, {'bond_weight': 0.2}),
#  (12, 37, {'bond_weight': 0.2}),
#  (12, 38, {'bond_weight': 0.2}),
#  (12, 39, {'bond_weight': 0.2}),
#  (12, 40, {'bond_weight': 0.2}),
#  (12, 42, {'bond_weight': 0.2}),
#  (12, 43, {'bond_weight': 0.2}),
#  (12, 44, {'bond_weight': 0.2}),
#  (12, 45, {'bond_weight': 0.2}),
#  (12, 46, {'bond_weight': 0.2}),
#  (12, 47, {'bond_weight': 0.2}),
#  (12, 48, {'bond_weight': 0.2}),
#  (12, 49, {'bond_weight': 0.2}),
#  (12, 50, {'bond_weight': 0.2}),
#  (12, 64, {'bond_weight': 0.2}),
#  (12, 65, {'bond_weight': 0.2}),
#  (12, 72, {'bond_weight': 0.2}),
#  (12, 73, {'bond_weight': 0.2}),
#  (12, 74, {'bond_weight': 0.2}),
#  (12, 75, {'bond_weight': 0.2}),
#  (12, 76, {'bond_weight': 0.2}),
#  (12, 77, {'bond_weight': 0.2}),
#  (12, 78, {'bond_weight': 0.2}),
#  (12, 86, {'bond_weight': 0.2}),
#  (12, 87, {'bond_weight': 0.2}),
#  (12, 90, {'bond_weight': 0.2}),
#  (12, 91, {'bond_weight': 0.2}),
#  (12, 115, {'bond_weight': 0.2}),
#  (12, 116, {'bond_weight': 0.2}),
#  (12, 120, {'bond_weight': 0.2}),
#  (12, 124, {'bond_weight': 0.2}),
#  (12, 125, {'bond_weight': 0.2}),
#  (12, 126, {'bond_weight': 0.2}),
#  (12, 127, {'bond_weight': 0.2}),
#  (12, 128, {'bond_weight': 0.2}),
#  (12, 129, {'bond_weight': 0.2}),
#  (12, 130, {'bond_weight': 0.2}),
#  (12, 131, {'bond_weight': 0.2}),
#  (12, 132, {'bond_weight': 0.2}),
#  (12, 133, {'bond_weight': 0.2}),
#  (12, 135, {'bond_weight': 0.2}),
#  (12, 136, {'bond_weight': 0.2}),
#  (12, 325, {'bond_weight': 0.2}),
#  (12, 359, {'bond_weight': 0.2}),
#  (12, 360, {'bond_weight': 0.2}),
#  (12, 392, {'bond_weight': 0.2}),
#  (12, 393, {'bond_weight': 0.2}),
#  (12, 396, {'bond_weight': 0.2}),
#  (12, 432, {'bond_weight': 0.2}),
#  (12, 433, {'bond_weight': 0.2}),
#  (12, 434, {'bond_weight': 0.2}),
#  (12, 435, {'bond_weight': 0.2}),
#  (12, 436, {'bond_weight': 0.2}),
#  (12, 437, {'bond_weight': 0.2}),
#  (12, 438, {'bond_weight': 0.2}),
#  (12, 439, {'bond_weight': 0.2}),
#  (12, 440, {'bond_weight': 0.2}),
#  (12, 448, {'bond_weight': 0.2}),
#  (12, 449, {'bond_weight': 0.2}),
#  (12, 450, {'bond_weight': 0.2}),
#  (12, 459, {'bond_weight': 0.2}),
#  (12, 460, {'bond_weight': 0.2}),
#  (12, 461, {'bond_weight': 0.2}),
#  (12, 462, {'bond_weight': 0.2}),
#  (12, 463, {'bond_weight': 0.2}),
#  (12, 464, {'bond_weight': 0.2}),
#  (12, 466, {'bond_weight': 0.2}),
#  (12, 468, {'bond_weight': 0.2}),
#  (12, 469, {'bond_weight': 0.2}),
#  (12, 496, {'bond_weight': 0.2}),
#  (12, 497, {'bond_weight': 0.2}),
#  (12, 498, {'bond_weight': 0.2}),
#  (12, 499, {'bond_weight': 0.2}),
#  (12, 500, {'bond_weight': 0.2}),
#  (12, 508, {'bond_weight': 0.2}),
#  (13, 14, {'bond_weight': 0.2}),
#  (13, 15, {'bond_weight': 0.2}),
#  (13, 16, {'bond_weight': 0.2}),
#  (13, 17, {'bond_weight': 0.2}),
#  (13, 19, {'bond_weight': 0.2}),
#  (13, 20, {'bond_weight': 0.2}),
#  (13, 23, {'bond_weight': 0.2}),
#  (13, 25, {'bond_weight': 0.2}),
#  (13, 28, {'bond_weight': 0.2}),
#  (13, 29, {'bond_weight': 0.2}),
#  (13, 30, {'bond_weight': 0.2}),
#  (13, 32, {'bond_weight': 0.2}),
#  (13, 35, {'bond_weight': 0.2}),
#  (13, 36, {'bond_weight': 0.2}),
#  (13, 37, {'bond_weight': 0.2}),
#  (13, 39, {'bond_weight': 0.2}),
#  (13, 42, {'bond_weight': 0.2}),
#  (13, 44, {'bond_weight': 0.2}),
#  (13, 47, {'bond_weight': 0.2}),
#  (13, 65, {'bond_weight': 0.2}),
#  (13, 66, {'bond_weight': 0.2}),
#  (13, 67, {'bond_weight': 0.2}),
#  (13, 68, {'bond_weight': 0.2}),
#  (13, 75, {'bond_weight': 0.2}),
#  (13, 76, {'bond_weight': 0.2}),
#  (13, 77, {'bond_weight': 0.2}),
#  (13, 78, {'bond_weight': 0.2}),
#  (13, 79, {'bond_weight': 0.2}),
#  (13, 80, {'bond_weight': 0.2}),
#  (13, 86, {'bond_weight': 0.2}),
#  (13, 87, {'bond_weight': 0.2}),
#  (13, 90, {'bond_weight': 0.2}),
#  (13, 91, {'bond_weight': 0.2}),
#  (13, 115, {'bond_weight': 0.2}),
#  (13, 116, {'bond_weight': 0.2}),
#  (13, 131, {'bond_weight': 0.2}),
#  (13, 132, {'bond_weight': 0.2}),
#  (13, 436, {'bond_weight': 0.2}),
#  (13, 437, {'bond_weight': 0.2}),
#  ...]

# %%
#Here we generate graph for each snapshots and save it into files
#This can reduce the dataloader time.

MDset_list = ["./data/ThreeCopies/7_1_1_conect_lifetimes/",
              "./data/ThreeCopies/7_2_1_conect_lifetimes/",
              "./data/ThreeCopies/7_3_1_conect_lifetimes/"]

pigment_dir_list = ['CLA610/',
            'CLA611/',
            'CLA612/',
            'LUT620/']

label_path = "./data/ThreeCopies/ThreeCopies_all_lifetimes.csv"




distance_cutoff = 7.5
weak_bond_weight = 0.2 #the rigid covalent bond weight is 1


for num, MDset_path in enumerate(MDset_list):
    print("processing MD data set:")
    print(MDset_path)
    data_list = [] # this stores the pre-processed torch data points as a list
    for index in range(1000):
        work_path = []
        for pigment_dir in pigment_dir_list:
            work_path.append(MDset_path + pigment_dir + 'frame' + str(index+1) + '.csv')
        #here we define the workpath for 4 pigments.
        G = generate_4_cluster_graph(work_path)
        G = adding_intermol_edge(G, distance_cutoff, weak_bond_weight)

        data_list.append(utils.from_networkx(G)) #append the datapoint to the list.

        print('Graph generation for frame %d has been done.' %index)
    
    save_path = './data/ThreeCopies/data/'
    for idx, data in enumerate(data_list):
        if num == 0:
            torch.save(data, save_path + 'data_as_graphs_25062021_frame' + str(idx) + '.pt')    
        elif num == 1:
            idx += 1000
            torch.save(data, save_path + 'data_as_graphs_25062021_frame' + str(idx) + '.pt')  
        elif num == 2:
            idx += 2000
            torch.save(data, save_path + 'data_as_graphs_25062021_frame' + str(idx) + '.pt')  
        print("data set No.%d saved" %num)
"""
    #here we seperate them in different files, so we don't access the whole, in order to save time.
    #for the ThreeCopies dataset. everything is stored together, numbering from copy 1 to copy 3, from 1 to 3000.
    save_path = './data/ThreeCopies/data/'
    for idx, data in enumerate(data_list):
        torch.save(data, save_path + 'data_as_graphs_25062021_frame' + str(idx) + '.pt')    
"""
# Out:
# processing MD data set:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame1.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame1.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21303
# Graph generation for frame 0 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame2.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame2.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame2.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame2.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame2.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame2.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame2.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame2.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21086
# Graph generation for frame 1 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame3.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame3.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame3.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame3.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame3.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame3.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame3.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame3.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21409
# Graph generation for frame 2 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame4.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame4.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame4.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame4.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame4.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame4.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame4.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame4.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21329
# Graph generation for frame 3 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame5.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame5.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame5.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame5.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame5.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame5.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame5.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame5.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21206
# Graph generation for frame 4 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame6.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame6.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame6.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame6.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame6.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame6.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame6.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame6.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21671
# Graph generation for frame 5 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame7.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame7.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame7.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame7.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame7.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame7.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame7.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame7.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21263
# Graph generation for frame 6 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame8.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame8.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame8.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame8.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame8.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame8.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame8.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame8.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 20795
# Graph generation for frame 7 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame9.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame9.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame9.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame9.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame9.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame9.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame9.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame9.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21078
# Graph generation for frame 8 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame10.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame10.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame10.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame10.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame10.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame10.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame10.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame10.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21382
# Graph generation for frame 9 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame11.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame11.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame11.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame11.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame11.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame11.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame11.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame11.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21200
# Graph generation for frame 10 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame12.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame12.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame12.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame12.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame12.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame12.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame12.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame12.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 20780
# Graph generation for frame 11 has been done.
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame13.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA610/frame13.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame13.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA611/frame13.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame13.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/CLA612/frame13.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame13.csv
# reading data from path:
# ./data/ThreeCopies/7_1_1_conect_lifetimes/LUT620/frame13.csv
# The node number for each graph are:
# 136 137 137 98
# The combined graph node number is: 508
# within the cutoff, the inter mol are:
# 21473

# %%
#torch.save(data_list, './data_as_graphs_20042021.pt')

# %%
import torch

# %%
#Test the graph generation.

from torch_geometric import utils
from torch_geometric.data import Data

# %%
data = utils.from_networkx(U_test2)

# %%
data

# %%
data.edge_index

# %%
from my_dataset_4cluster_2 import *

# %%
My_dataset()

# %%
for element in My_dataset():
    print(element)
    a = element
    break

# %%
np.random.seed(1)
torch.random.manual_seed(1)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
############################################################################
#data loader initalization
#DATA_PATH = './data/'
dataset_size = 1000
perm = torch.randperm(dataset_size).numpy()
partition = {}
partition["train"] = perm[:int(dataset_size*8/10)]
partition["validation"] = perm[int(dataset_size*8/10):int(dataset_size*9/10)]
partition["test"] = perm[int(dataset_size*9/10):]

train_loader = DataLoader(torch.utils.data.Subset(My_dataset(), partition["train"]), 
                          batch_size=16, 
                          #sampler=train_sampler,
                          shuffle=True, 
                          num_workers=8)

# %%
for element in train_loader:
    print(element)
    break
